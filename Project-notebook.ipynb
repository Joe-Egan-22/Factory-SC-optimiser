# %% [markdown]
# # Factory-SC-optimiser project notebook
#
# This file will be used for any detail of theory or ideas which are not necessary to the main code file. NB, main changes will be recorded in commits rather than here.

# %% [markdown]
# ## Stage 1
#
# Read appropriate csvs and treat as simple profit maximisation based on few constrains. Aim to solve this for day/weekly production of items and then evolve from there.

# %% [markdown]
# Objective: Maximise profits
#
# Decision variables: Number of products to produce per unit time (TBD)
#
# Constraints: Raw materials, employee working time, machine time

# %% [markdown]
# ## Stage 2
#
# Now that code can solve basic LP problem, will move on to adding an additional feature.

# %% [markdown]
# ### Validation
#
# Before moving on to stage 2, will create a validation function:
#
# - [x] Does every product have a profit?
#
# - [x] Does every product have machine hours?
# - [x] Does every product have labour hours?
# - [x] Does every BOM product exist in the product database?
# - [x] Does every BOM material exist in the inventory?
# - [ ] Are quantities non-negative? (not needed yet)
# - [X] Are ProductIDs unique?
# - [X] Are MaterialIDs unique?
# - [x] Are there missing values?

# %% [markdown]
# ### AI-suggestions
#
# Consulted AI for code-quality suggestions before moving forward
#
# - [ ] Make validation fail safely rather than just print warnings.
# - [ ] Validate numerical values and data types.
# - [ ] Fix/clarify BOM duplicate handling.
# - [ ] Change AvailableTime to a simpler structure and eventually move capacities into input data/configuration.
# - [ ] Handle solver statuses properly.
# - [ ] Return structured results rather than only printing them.
# - [ ] Decide whether production variables should be continuous or integer.
# - [ ] Add demand constraints if the problem is intended to represent real production planning.
# - [ ] Separate loading, validation, preparation, modelling, solving and reporting.
# - [ ] Only then worry about performance/style optimisations.
#
# Additionally, my own suggestions are...
#
# - [ ] Create seperate functions for constraint types

# %% [markdown]
# ### New feature: Additional constraints

# %% [markdown]
# ## Stage 3: Shadow prices
#
# Will now extract more useful information from the LP solution (requires personal theory research first)
