# %% [markdown]
# # Factory-SC-optimiser project notebook
#
# This file will be used for any detail of theory or ideas which are not necessary to the main code file. NB, main changes will be recorded in commits rather than here.
